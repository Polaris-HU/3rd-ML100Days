# %%
import numpy as np
import matplotlib.pyplot as plt

w=3
b=0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
def mean_squared_error(y,yp):
    mse=MSE=sum((y-yp)**2)
    return mse

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 23408.761
# The Mean absolute error is 12.129

# %% [markdown]
# 作業2
# 1.我所選擇的是MLB官方的各種投打紀錄的資料庫，在球賽中投手的初速、轉速、球種等等，都會影響到打者的打擊率。
# 2.資料是由MLB官方紀錄組所提供，從2015-2018。
# 3.他是一種結構化的呈現方法包含直方圖，數值。
# 4.我們可以透過單一選手的球季中的表現，球的轉速、球的速度來分析此投手今年成績下滑的主要原因，以及影響投手表現的關鍵因素。

# %% [markdown]
# 作業3
# 1.由尖峰時段跟離峰時段，來分配車隊待命的人數，根據數據來減少成本支出，增加尖峰時段的車量，減少離峰時段的車量。
# 2.利用攝影機，將重要交通地帶人潮多寡變化做估算。
# 3.資料為非結構化的資料
# 4.將改變過後的利潤，跟未改變之前的利潤，做比較，以及改變前後的成本支出差距。
